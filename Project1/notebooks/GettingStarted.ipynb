# %% [markdown]
# Author: **Priyam Halder**
# Date: 10/05/2026

# %% [markdown]
# Let's read retail_sales.csv

# %%
help(spark.read)

# %%
df = (
    spark.read
         .format("csv")
         .option("header", "true")
         .option("inferSchema", "true")
         .load("/Workspace/Users/priyam.halder991@gmail.com/Databricks_Learning/Project1/data/retail_sales.csv")
)

# %%
display(df)

# %%
df.show()

# %%
df.printSchema()

# %%
df.count()

# %%
len(df.columns)

# %%
df.columns

# %%
df.describe().show()

# %%
display(df.limit(5))

# %%
df.select("Store_Name", "City").show()

# %%
df.filter(df.Unit_Price > 600).show()

# %%
df.orderBy(df.Unit_Price.desc()).show()

# %%
df.select("Product_Category").distinct().show()

# %%
from pyspark.sql.functions import col, sum

df.select(
    [sum(col(c).isNull().cast("int")).alias(c) for c in df.columns]
).show()

# %%
df.dtypes

# %%
df.cache

# %%
df.count()

# %%
filtered_df = df.filter(df.Unit_Price > 600)
filtered_df.createOrReplaceTempView("filtered_df")
filtered_df.show()
filtered_df.explain()

# %%
df.write.mode("overwrite").saveAsTable("retail_sales_table")

# %%
# %sql
select * from retail_sales_table where Unit_Price>600
